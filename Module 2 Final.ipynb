# %% [markdown]
# ## Module_2: Fibrosis
#
# ## Team Members: Noah Edouard and Stella Perini
#
#
# ## Project Title: Spatial profiling of fibrosis in lung tissue: interpolation and prediction across tissue depth

# %% [markdown]
# ## Project Goal:
# This project seeks to quantify how the extent of fibrosis changes with depth through fibrotic lung tissue and to build an interpolation model that predicts fibrosis fraction at arbitrary depths between measured samples. Using image-derived fibrosis metrics sampled at known depths, we will (1) describe the depth-dependent pattern of fibrosis (e.g., subpleural vs. central), (2) test interpolation methods (linear, spline, local regression) to predict fibrosis at unmeasured depths, and (3) evaluate prediction accuracy and uncertainty.

# %% [markdown]
# ## Disease Background:
# Overall background:
# Idiopathic pulmonary fibrosis (IPF) is a progressive debilitating lung disease where lung tissue becomes permanently scarred, thickened, and stiff leading to difficulty in breathing and a dry cough.
# The term idiopathic is used because its cause is completely unknown, however, there are risks factors such as smoking, older age, and family history that
#
# Prevalence & incidence
#
# Prevalence in the US:
# - 14.0 to 27.9 cases per 100,000 people
# - affecting approximately 100,000 to 200,000 people in the United States
# - Prevalence is increasing globally and are higher in older age groups, more common in males and caucasian hispanics
# - Annual incidence rates are estimated between 6.8 and 8.8 per 100,000 population
# - Overall, this study estimated the adjusted incidence and prevalence to be in the rang of 0.09-1.30 and 0.33-4.51 per 10,000 persons worldwide, and according to this, IPF remains a rare disease.
#
# Incidence in the US:
# - Approximately 6.8 to 16.3 new cases per 100,000 people
# - Up to approximately 140,000 people are living with IPF in teh US and about 50,000 are diagnosed with IPF annually
# https://respiratory-research.biomedcentral.com/articles/10.1186/s12931-021-01791-z
# https://pro.boehringer-ingelheim.com/us/insights-in-ild/diseases/epidemiology-ipf
#
#
# Risk factors (genetic, lifestyle)
#
# Genetic Factors:
# - Genetic variation accounts for at least one-third of the risk of developing the disease
# - Single-most validated and most significant risk factor is a gain-of-function promoter variant in the MUC5B gene → validated in multiple independent studies
# - The MUC5B gene makes a mucus protein that promotes the clearing of substances in the lings
# - TERT and TERC genes → genes that produce the enzyme telomerase which protects the ends of chromosomes during cell division
# -Other genes: mutations in genes for surfactant proteins  and alveolar epithelial cell function can lead to increased alveolar instability and cell death
# - A harmful variant in just one copy of a gene (from either parents) can be enough to increase a person's risk of developing IPF → children of a parents with an IPF-linked gene variant have a 50% chance of inheriting the variant, but this does not guarantee the development of the disease.
# https://pmc.ncbi.nlm.nih.gov/articles/PMC7801923/
#
# Lifestyle Factors:
# - Age: the risk of IPF increases as you increase in age, it is most commonly diagnosed in people who are in their 60s or 70s
# - Smoking is a common risk factor → smoking's association with shortening telomeres, the DNA structures that protect your cells, which are linked to age-related diseases
# - IPF is more common among men than women
# - Silica dust exposure, common in construction, mining, sandblasting, and stonework industries, poses another significant risk factor
# Certain viral infections such as gastroesophageal reflux disease
#  Certain chemotherapy agents used in cancer treatment are known to cause lung toxicity that may progress to fibrosis.
# https://www.nhlbi.nih.gov/health/idiopathic-pulmonary-fibrosis/causes
#
# Symptoms
# - Shortness of breath, requiring greater effort to breathe→ physical activity and can be improperly misdiagnosed as aging or lack of fitness
# - The most common early symptom is a persistent dry cough that doesn’t respond to typical cough remedies or resolve with time. This cough is typically nonproductive, meaning it doesn’t bring up mucus or phlegm, and may be particularly bothersome at night or when lying down. Unlike coughs associated with respiratory infections, this persistent cough tends to worsen gradually over weeks or months.
# - Weight loss
# - Unexplained fatigue and decreased energy levels frequently accompany the respiratory symptoms
# - Aching of muscles
# - Rapid, shallow breathing
# - Some patients experience a gradual, steady decline in lung function over several years, while others may have periods of relative stability followed by rapid deterioration
# - As scarring spreads throughout the lungs, patients typically experience worsening shortness of breath, decreased exercise tolerance, and other symptoms that significantly impact their quality of life and daily functioning.
# digital clubbing, which affects the fingers and sometimes the toes. Clubbing involves enlargement of the fingertips and changes in the nail beds
# https://halohale.com/conditions/pulmonary-fibrosis-causes-symptoms-diagnostic-testing/?gad_source=1&gad_campaignid=22372592542&gbraid=0AAAAAC_9opiCFu2YwO0_09BVg2Vd9dryJ&gclid=Cj0KCQjw9JLHBhC-ARIsAK4PhcqBX1uJUvVIkulp7I0cI6E3ukIsQ0I6u8j9PHDL1CZgSFR-HhB03NkaAir2EALw_wcB
#
# Standard of care treatment(s)
# - Accurate diagnosis is a long and difficult process combining clinical assessment, imaging studies, pulmonary function testing and sometimes specialized procedures
# - Diagnosis process confirms the presence of the disease but also its type, severity and identify underlying causes that may influence management approaches
# - Initial medical evaluation → medical history assessment involving any work involving dust, chemicals or harmful substances.
# - Documenting the timeline and progression of symptoms provides crucial information about disease development and severity
# - Physical examination → respiratory and cardiovascular systems, such as listening carefully to lung sounds and listening for abnormal sounds from opening scarred air sacs
# - Examining fingers and toes for clubbing
# - Imaging studies → chest X-rays but have many limitations and may appear normal in the early stages.
# - HRCT → gold standard for imaging IPR and provides a detailed visualization of lung structure and scarred patterns. → shows the appearance of honeycombing
# - Pulmonary function tests → objective measurements of lung capacity and function that can offer information about disease severity and progression
# - Diffusion capacity testing (DLCO) → measures how effectively oxygen transfers from the lungs to the blood stream.
#
# Biological mechanisms (anatomy, organ physiology, cell & molecular physiology)
#
# Main idea: pathologic findings in pulmonary fibrosis is excessive accumulation of extracellular matrix ,ECM, and remodeling of lung architecture. ECM experiences excessive accumulation of collegens, leading to tissue stiffening and impaired organ function.
# - When the balance between fibroblast proliferation and apoptosis is shifted toward accelerated proliferation or slowed apoptosis, fibroblasts - the primary ECM producers - accumulate
#
# Alveolar Epithelial Cell dysfunction:
# - Initial and repeated insults to alveolar epithelial cells trigger disease progression
# - Exhibit signs of aging, including telomere, mitochondrial dysfunction, DNA dama and inflammatory senescence
# - Loss of Alveolar structure → relentless accumulation of ECM replaces normal lung tissue and destroys the alveoli
# - Decreased lung function
# - Impaired tissue homestatus → chronic injury and repair results in fibrosis
# abnormalities of the alveolar epithelium in patients with pulmonary fibrosis have been noted from the earliest descriptions of the disease process
# https://pmc.ncbi.nlm.nih.gov/articles/PMC3443459/

# %% [markdown]
# ## Data-Set:
# The dataset consists of a series of immunofluorescent images of mouse lung tissue sections taken at multiple depths following induction of pulmonary fibrosis. The tissue originates from mice treated with Bleomycin, a chemotherapeutic drug that induces lung fibrosis, thereby serving as a model for idiopathic pulmonary fibrosis (IPF). The final dataset includes black-and-white images representing fibrosis (white regions = fibrotic lesions; black regions = healthy lung tissue) collected across the depth of both left and right lungs.
#
# Source of Data
#
# - The data is derived from experimental mouse models of pulmonary fibrosis created using the Bleomycin-induced lung injury model. This method is a widely used preclinical model to study lung fibrosis and mimic aspects of IPF pathology.
#
# Data Collection Methods and Techniques
# Induction of Fibrosis:
# - Mice were treated with intratracheal Bleomycin. After three weeks, the animals were euthanized, and their lungs were harvested for analysis.
#
#
# Tissue Preparation:
# - Lungs were frozen in OCT compound to preserve tissue morphology.
# - Using a cryotome, the tissue was sectioned in the transverse plane, allowing for imaging at successive tissue depths.
#
#
# Microscopy & Imaging:
# - Fluorescence microscopy was performed to capture digital images of the stained sections.
# - The desmin channel was isolated and converted into black-and-white images, where white regions indicate fibrotic lesions and black regions indicate healthy lung tissue.
# - A total of 78 images were collected at different depths ranging from 0 µm to 10,000 µm into the lung.
#
# Units of Measurement
# - Depth of tissue sections: measured in micrometers (µm).
# - Fibrosis representation: binary image (white = fibrotic lesion, black = healthy lung).
# - Protein localization: fluorescence intensity signals corresponding to each antibody marker.
#
# Relevant Information
# - The dataset captures three-dimensional information about lung fibrosis progression by stacking images from different depths.
# - It enables quantification of fibrosis by measuring the proportion of fibrotic (white) vs. healthy (black) tissue.
# - Co-staining with other markers (smooth muscle actin, CD-31) provides insight into how fibrosis interacts with blood vessels and myofibroblast proliferation.

# %% [markdown]
# ## Data Analysis:

# %%
'''Module 2: count black and white pixels in a .jpg and extrapolate points'''

from termcolor import colored
import cv2
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
import pandas as pd

# Load the images you want to analyze

filenames = [
    r"C:\Users\lafor\OneDrive\Module 2\MASK_Sk658 Llobe ch010017.jpg",
    r"C:\Users\lafor\OneDrive\Module 2\MASK_Sk658 Llobe ch010018.jpg",
    r"C:\Users\lafor\OneDrive\Module 2\MASK_Sk658 Llobe ch010019.jpg",
    r"C:\Users\lafor\OneDrive\Module 2\MASK_Sk658 Llobe ch010021.jpg",
    r"C:\Users\lafor\OneDrive\Module 2\MASK_Sk658 Llobe ch010022.jpg",
    r"C:\Users\lafor\OneDrive\Module 2\MASK_Sk658 Llobe ch010023.jpg",
            ]

# Enter the depth of each image (in the same order that the images are listed above; you can find these in the .csv file provided to you which is tilted: "Filenames and Depths for Students")

depths = [
    45,
    90,
    60,
    30,
    80,
    100
    ]

# Make the lists that will be used

images = []
white_counts = []
black_counts = []
white_percents = []

# Build the list of all the images you are analyzing

for filename in filenames:
    img = cv2.imread(filename, 0)
    images.append(img)

# For each image (until the end of the list of images), calculate the number of black and white pixels and make a list that contains this information for each filename.

for x in range(len(filenames)):
    _, binary = cv2.threshold(images[x], 127, 255, cv2.THRESH_BINARY)

    white = np.sum(binary == 255)
    black = np.sum(binary == 0)

    white_counts.append(white)
    black_counts.append(black)

# Print the number of white and black pixels in each image.

print(colored("Counts of pixel by color in each image", "yellow"))
for x in range(len(filenames)):
    print(colored(f"White pixels in image {x}: {white_counts[x]}", "white"))
    print(colored(f"Black pixels in image {x}: {black_counts[x]}", "black"))
    print()

# Calculate the percentage of pixels in each image that are white and make a list that contains these percentages for each filenamae

for x in range(len(filenames)):
    white_percent = (100 * (white_counts[x] / (black_counts[x] + white_counts[x])))
    white_percents.append(white_percent)

# Print the filename (on one line in red font), and below that line print the percent white pixels and depth

print(colored("Percent white px:", "yellow"))
for x in range(len(filenames)):
    print(colored(f'{filenames[x]}:',"red"))
    print(f'{white_percents[x]}% White | Depth: {depths[x]} microns')
    print()

'''Write your data to a .csv file'''

# Create a DataFrame that includes the filenames, depths, and percentage of white pixels
df = pd.DataFrame({
    'Filenames': filenames,
    'Depths': depths,
    'White percents': white_percents       
})

# Write that DataFrame to a .csv file

df.to_csv('Percent_White_Pixels.csv', index=False)

print("CSV file 'Percent_White_Pixels.csv' has been created.")

'''the .csv writing subroutine ends here'''

# Interpolate a point: given a depth, find the corresponding white pixel percentage

interpolate_depth = float(input(colored("Enter the depth at which you want to interpolate a point: ", "yellow")))

x = depths
y = white_percents

i = interp1d(x, y, kind='linear')  # You can also use 'quadratic', 'cubic', etc.
interpolate_point = i(interpolate_depth)
print(colored(f'The interpolated point is at the x-coordinate {interpolate_depth} and y-coordinate {interpolate_point}.', "green"))

depths_i = depths[:]
depths_i.append(interpolate_depth)
white_percents_i = white_percents[:]
white_percents_i.append(interpolate_point)

# make two plots: one that doesn't contain the interpolated point, just the data calculated from your images, and one that also contains the interpolated point (shown in red)
fig, axs = plt.subplots(2, 1)

axs[0].scatter(depths, white_percents, marker='o', linestyle='-', color='blue')
axs[0].set_title('Plot of depth of image vs percentage white pixels')
axs[0].set_xlabel('depth of image')
axs[0].set_ylabel('white pixels as a percentage of total pixels')
axs[0].grid(True)


axs[1].scatter(depths_i, white_percents_i, marker='o', linestyle='-', color='blue')
axs[1].set_title('Plot of depth of image vs percentage white pixels w/ interpolated point (red)')
axs[1].set_xlabel('depth of image')
axs[1].set_ylabel('white pixels as a percentage of total pixels')
axs[1].grid(True)
axs[1].scatter(depths_i[len(depths_i)-1], white_percents_i[len(white_percents_i)-1], color='red', s=100, label='Highlighted point')


# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()

i = interp1d(x, y, kind='quadratic')  # You can also use 'quadratic', 'cubic', etc.
interpolate_point = i(interpolate_depth)
print(colored(f'The interpolated point is at the x-coordinate {interpolate_depth} and y-coordinate {interpolate_point}.', "green"))

depths_i = depths[:]
depths_i.append(interpolate_depth)
white_percents_i = white_percents[:]
white_percents_i.append(interpolate_point)

# make two plots: one that doesn't contain the interpolated point, just the data calculated from your images, and one that also contains the interpolated point (shown in red)
fig, axs = plt.subplots(2, 1)

axs[0].scatter(depths, white_percents, marker='o', linestyle='-', color='blue')
axs[0].set_title('Plot of depth of image vs percentage white pixels')
axs[0].set_xlabel('depth of image')
axs[0].set_ylabel('white pixels as a percentage of total pixels')
axs[0].grid(True)


axs[1].scatter(depths_i, white_percents_i, marker='o', linestyle='-', color='blue')
axs[1].set_title('Plot of depth of image vs percentage white pixels w/ interpolated point (red)')
axs[1].set_xlabel('depth of image')
axs[1].set_ylabel('white pixels as a percentage of total pixels')
axs[1].grid(True)
axs[1].scatter(depths_i[len(depths_i)-1], white_percents_i[len(white_percents_i)-1], color='red', s=100, label='Highlighted point')


# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()
# Out:
# Counts of pixel by color in each image
# White pixels in image 0: 27561
# Black pixels in image 0: 4166743
#
# White pixels in image 1: 33746
# Black pixels in image 1: 4160558
#
# White pixels in image 2: 31331
# Black pixels in image 2: 4162973
#
# White pixels in image 3: 23900
# Black pixels in image 3: 4170404
#
# White pixels in image 4: 33151
# Black pixels in image 4: 4161153
#
# White pixels in image 5: 37508
# Black pixels in image 5: 4156796
#
# Percent white px:
# C:\Users\lafor\OneDrive\Module 2\MASK_Sk658 Llobe ch010017.jpg:
# 0.6571054458618164% White | Depth: 45 microns
#
# C:\Users\lafor\OneDrive\Module 2\MASK_Sk658 Llobe ch010018.jpg:
# 0.8045673370361328% White | Depth: 90 microns
#
# C:\Users\lafor\OneDrive\Module 2\MASK_Sk658 Llobe ch010019.jpg:
# 0.7469892501831055% White | Depth: 60 microns
#
# C:\Users\lafor\OneDrive\Module 2\MASK_Sk658 Llobe ch010021.jpg:
# 0.5698204040527344% White | Depth: 30 microns
#
# ...

# %% [markdown]
# ## Verify and validate your analysis:
# Verification
#
# The linear interpolation and quadratic interpolation varied by roughly only 3 thousandths, 0.7170279820760092 and 0.7208952863526993. Just looking at the graph visually, the white blood cell percentages are increasing as the depth increases. Our two white percent values agree with this trend. This confirms accuracy in code and biological plausibility.
#
# Validation
#
# For validation we compared our results to the image provided by Dr.Pierce-Cottler. According to Dr.Pierce-Cottler’s image, the white blood cell percentage at 55 micrometers is 0.707554817199707% which agrees with our two interpolated values. We also validated our data with a study in mice that supports the concept of fibrosis increasing with lung depth (i.e., being subpleural or peripheral) is titled "Bleomycin induces pleural and subpleural fibrosis in the presence of carbon particles" (Respiratory Research, 2009). The research aimed to create a mouse model that better mimicked the human condition of Idiopathic Pulmonary Fibrosis (IPF), which is defined by fibrosis that is strongest in the lung periphery (subpleural region) and bases. The study found that administering carbon particles intrapleurally (into the chest cavity, adjacent to the lung surface) along with bleomycin (a common fibrogenic agent) led to severe pleural fibrosis and progressive fibrosis in the subpleural lung regions, a distribution that the authors explicitly noted was "similar to IPF in humans." This finding demonstrates a mouse model where the fibrotic reaction is intentionally concentrated at the periphery/depth of the lung tissue, providing a tangible source for this pattern in mice. The validation data matches the our results.

# %% [markdown]
# ## Conclusions and Ethical Implications:
# Our analysis indicated that the percentage of fibrotic white tissue increases with lung depth which is consistent with biological expectations and published literature. Both the linear and quadratic interpolations produced similar results, differing only by a few thousands which supports the accuracy of our computational methods. The interpolated value of 55 microns closely matched the reference value from Dr. Pierce-Cottlers image which confirms the validity of our approach.
# Transparency in analysis within an experiment and validation against trusted biological references are critical. Clinical deeper lung biopsies are highly invasive and carry greater clinical risks such as pneumothorax which is a lung collapse. Overall, there needs to be a balance between diagnostic accuracy and patient safety.
# On the other hand, there is a big ethical responsibility in scientists when they are doing animal clinical research. It is important to minimize harm and distress to animals and understand that their data findings don’t 100% accurately reflect human pathology. Including human clinical data where available is essential to confirming conclusions.

# %% [markdown]
# ## Limitations and Future Work:
#  Our analysis shows that fibrotic tissue increases with lung depth which aligns with biological expectation and published literature. However, this conclusion is based on a very limited dataset of only six images, which restricts our analysis and conclusion. In the future, we will expand the dataset with additional measurements that would overall improve accuracy and allow for more comprehensive modeling. Additionally, the accuracy of the white tissue may be affected by image resolution.
#  Some additional future work ideas would be to incorporate machine learning algorithms to reduce manual interpretation of interpolation. This could potentially improve precision. Another future idea could be to do a cross-species validation by comparing data with human biopsy or imaging data to the data obtained by mice, this would check if your findings can translate from the animal model to the human disease. Another idea is to measure lung stiffness to understand mechanical resistance with lung depth. And lastly, I would explore whether imaging or sensing technology could be less invasive, possibly invent a new biomedical device or research a new one.

# %% [markdown]
# ## NOTES FROM YOUR TEAM:
#
# Session 1 and 2:
#
# Task:
# - Begin working on first check-in
# - Stella: complete all sections in blue
# - Noah: complete all sections in red
# - Both: Make sure terminal is working properly
#
# Session 3
#
# Task:
# - Completed linear interpolation
# - Completed quadratic interpolation
# - Begin to research and interpret the data we found
# - Noah: Work on validation and verification
# - Stella: Work on conclusion, future work, and limitations
#
# https://docs.google.com/document/d/1ePvCnI1cWl-ZvvFz5ur97r3s4NVHImOLJLfvQZxDYq4/edit?tab=t.0

# %% [markdown]
# ## QUESTIONS FOR YOUR TA:
# No questions for our TA
