# %%
import pandas as pd

# Data
data = {
    "Filenames": [
        r"C:\Users\lafor\OneDrive\Module 2\MASK_Sk658 Llobe ch010017.jpg",
        r"C:\Users\lafor\OneDrive\Module 2\MASK_Sk658 Llobe ch010018.jpg",
        r"C:\Users\lafor\OneDrive\Module 2\MASK_Sk658 Llobe ch010019.jpg",
        r"C:\Users\lafor\OneDrive\Module 2\MASK_Sk658 Llobe ch010021.jpg",
        r"C:\Users\lafor\OneDrive\Module 2\MASK_Sk658 Llobe ch010022.jpg",
        r"C:\Users\lafor\OneDrive\Module 2\MASK_Sk658 Llobe ch010023.jpg"
    ],
    "Depths": [45, 60, 80, 570, 955, 2800],
    "White percents": [
        0.6571054458618164,
        0.8045673370361328,
        0.7469892501831055,
        0.5698204040527344,
        0.7903814315795898,
        0.8942604064941406
    ]
}

# Create DataFrame
df = pd.DataFrame(data)

# Save as CSV
df.to_csv("fibrosis_table.csv", index=False)

# Show table in terminal
print("\n✅ Table created:\n")
print(df.to_string(index=False))
# Out:
# ✅ Table created:
#
#                                                      Filenames  Depths  White percents
# C:\Users\lafor\OneDrive\Module 2\MASK_Sk658 Llobe ch010017.jpg      45        0.657105
# C:\Users\lafor\OneDrive\Module 2\MASK_Sk658 Llobe ch010018.jpg      60        0.804567
# C:\Users\lafor\OneDrive\Module 2\MASK_Sk658 Llobe ch010019.jpg      80        0.746989
# C:\Users\lafor\OneDrive\Module 2\MASK_Sk658 Llobe ch010021.jpg     570        0.569820
# C:\Users\lafor\OneDrive\Module 2\MASK_Sk658 Llobe ch010022.jpg     955        0.790381
# C:\Users\lafor\OneDrive\Module 2\MASK_Sk658 Llobe ch010023.jpg    2800        0.894260
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
